# %% [markdown]
# <a href="https://colab.research.google.com/github/sidharth-ds/Access-Data-via-Python/blob/main/to_read_Excel_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * importing Pandas to read the file:
#
# ---

# %%
import pandas as pd

# %% [markdown]
# * to Upload files:
#
# ---

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-efcc85fd-69a1-4059-baac-b58135fd3106" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-efcc85fd-69a1-4059-baac-b58135fd3106">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Admittance.csv to Admittance.csv
# ...

# %% [markdown]
# # to Read the files:

# %%
a = pd.read_csv("/content/Countries_exercise.csv")

# %%
b = pd.read_csv("/content/Country clusters.csv")

# %%
c = pd.read_csv("/content/Wine_Quality_Data.csv")

# %%
a
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %%
b
# Out:
#      Country  Latitude  Longitude Language
# 0        USA     44.97    -103.77  English
# 1     Canada     62.40     -96.80  English
# 2     France     46.75       2.40   French
# 3         UK     54.01      -2.53  English
# 4    Germany     51.15      10.40   German
# 5  Australia    -25.45     133.11  English

# %%
c
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  ...  alcohol  quality  color
# 0               7.4              0.70         0.00  ...      9.4        5    red
# 1               7.8              0.88         0.00  ...      9.8        5    red
# 2               7.8              0.76         0.04  ...      9.8        5    red
# 3              11.2              0.28         0.56  ...      9.8        6    red
# 4               7.4              0.70         0.00  ...      9.4        5    red
# ...             ...               ...          ...  ...      ...      ...    ...
# 6492            6.2              0.21         0.29  ...     11.2        6  white
# 6493            6.6              0.32         0.36  ...      9.6        5  white
# 6494            6.5              0.24         0.19  ...      9.4        6  white
# 6495            5.5              0.29         0.30  ...     12.8        7  white
# 6496            6.0              0.21         0.38  ...     11.8        6  white
#
# ...

# %% [markdown]
# * to Describe the Columns containing Numbers only:
#
# ---

# %%
c.describe()
# Out:
#        fixed_acidity  volatile_acidity  ...      alcohol      quality
# count    6497.000000       6497.000000  ...  6497.000000  6497.000000
# mean        7.215307          0.339666  ...    10.491801     5.818378
# std         1.296434          0.164636  ...     1.192712     0.873255
# min         3.800000          0.080000  ...     8.000000     3.000000
# 25%         6.400000          0.230000  ...     9.500000     5.000000
# 50%         7.000000          0.290000  ...    10.300000     6.000000
# 75%         7.700000          0.400000  ...    11.300000     6.000000
# max        15.900000          1.580000  ...    14.900000     9.000000
#
# [8 rows x 12 columns]

# %% [markdown]
# * to display the Information about the file:
#
# ---

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    6 non-null      object
#  1   Latitude   6 non-null      float64
#  2   Longitude  6 non-null      float64
#  3   Language   6 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 320.0+ bytes

# %% [markdown]
# # row-wise and column-wise filteration

# %% [markdown]
# * to access a particular Row:
#
# ---

# %%
c.iloc[1]
# Out:
# fixed_acidity              7.8
# volatile_acidity          0.88
# citric_acid                  0
# residual_sugar             2.6
# chlorides                0.098
# free_sulfur_dioxide         25
# total_sulfur_dioxide        67
# density                 0.9968
# pH                         3.2
# sulphates                 0.68
# alcohol                    9.8
# quality                      5
# color                      red
# Name: 1, dtype: object

# %% [markdown]
# * to access a range of Rows:
#
# ---

# %%
c.iloc[:7]
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  ...  alcohol  quality  color
# 0            7.4              0.70         0.00  ...      9.4        5    red
# 1            7.8              0.88         0.00  ...      9.8        5    red
# 2            7.8              0.76         0.04  ...      9.8        5    red
# 3           11.2              0.28         0.56  ...      9.8        6    red
# 4            7.4              0.70         0.00  ...      9.4        5    red
# 5            7.4              0.66         0.00  ...      9.4        5    red
# 6            7.9              0.60         0.06  ...      9.4        5    red
#
# [7 rows x 13 columns]

# %% [markdown]
# * to display first 5 rows:
#
# ---

# %%
a.head()
# Out:
#           name  Longitude   Latitude
# 0        Aruba -69.982677  12.520880
# 1  Afghanistan  66.004734  33.835231
# 2       Angola  17.537368 -12.293361
# 3     Anguilla -63.064989  18.223959
# 4      Albania  20.049834  41.142450

# %% [markdown]
# * wrong ranging:
#
# ---

# %%
c.iloc[3:1]
# Out:
# Empty DataFrame
# Columns: [fixed_acidity, volatile_acidity, citric_acid, residual_sugar, chlorides, free_sulfur_dioxide, total_sulfur_dioxide, density, pH, sulphates, alcohol, quality, color]
# Index: []

# %% [markdown]
# * to access a Column:
#
#
# ---

# %%
c['alcohol']
# Out:
# 0        9.4
# 1        9.8
# 2        9.8
# 3        9.8
# 4        9.4
#         ...
# 6492    11.2
# 6493     9.6
# 6494     9.4
# 6495    12.8
# 6496    11.8
# Name: alcohol, Length: 6497, dtype: float64

# %% [markdown]
# * to access multiple Columns:
#
# ---

# %%
c[['alcohol','chlorides']]
# Out:
#       alcohol  chlorides
# 0         9.4      0.076
# 1         9.8      0.098
# 2         9.8      0.092
# 3         9.8      0.075
# 4         9.4      0.076
# ...       ...        ...
# 6492     11.2      0.039
# 6493      9.6      0.047
# 6494      9.4      0.041
# 6495     12.8      0.022
# 6496     11.8      0.020
#
# [6497 rows x 2 columns]

# %% [markdown]
# * row-wise and column-wise Filteration:
#
# ---

# %%
a.loc[:,['name','Latitude']]
# Out:
#              name   Latitude
# 0           Aruba  12.520880
# 1     Afghanistan  33.835231
# 2          Angola -12.293361
# 3        Anguilla  18.223959
# 4         Albania  41.142450
# ..            ...        ...
# 236         Samoa -13.753243
# 237         Yemen  15.909280
# 238  South Africa -29.000341
# 239        Zambia -13.458242
# 240      Zimbabwe -19.004204
#
# [241 rows x 2 columns]

# %% [markdown]
# * to access particular row and particular column :
#
# ---

# %%
a.loc[a.index[[2,4,8]],['name']]
# Out:
#         name
# 2     Angola
# 4    Albania
# 8  Argentina

# %% [markdown]
# * to access range of rows and particular column :
#
# ---

# %%
a.loc[a.index[1:8],['name']]
# Out:
#                    name
# 1           Afghanistan
# 2                Angola
# 3              Anguilla
# 4               Albania
# 5                 Aland
# 6               Andorra
# 7  United Arab Emirates

# %%
a.loc[a.index[1:8],['name','Latitude']]
# Out:
#                    name   Latitude
# 1           Afghanistan  33.835231
# 2                Angola -12.293361
# 3              Anguilla  18.223959
# 4               Albania  41.142450
# 5                 Aland  60.214887
# 6               Andorra  42.542291
# 7  United Arab Emirates  23.905282

# %% [markdown]
# # Operations : > , >= , < , <= , == , != , and, not, nor

# %% [markdown]
# * output in boolean:
#
# ---

# %%
a['Latitude'] < 15
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 236     True
# 237    False
# 238     True
# 239     True
# 240     True
# Name: Latitude, Length: 241, dtype: bool

# %% [markdown]
# * actual output:
#
# ---

# %%
a[ a['Latitude'] < 15 ]
# Out:
#                       name   Longitude   Latitude
# 0                    Aruba  -69.982677  12.520880
# 2                   Angola   17.537368 -12.293361
# 8                Argentina  -65.179807 -35.381349
# 10          American Samoa -170.718026 -14.304460
# 11              Antarctica   19.921090 -80.508579
# ..                     ...         ...        ...
# 235  Wallis and Futuna Is. -177.348348 -13.887370
# 236                  Samoa -172.164851 -13.753243
# 238           South Africa   25.083901 -29.000341
# 239                 Zambia   27.774759 -13.458242
# 240               Zimbabwe   29.851441 -19.004204
#
# [107 rows x 3 columns]

# %% [markdown]
# # Unstructured data:

# %% [markdown]
# * import numpy to deal with Null values:
#
# ---

# %%
import numpy as np

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

# %%
data
# Out:
# {'age': [2.5, 3, 0.5, nan, 5, 2, 4.5, nan, 7, 3],
#  'animal': ['cat',
#   'cat',
#   'snake',
#   'dog',
#   'dog',
#   'cat',
#   'snake',
#   'cat',
#   'dog',
#   'dog'],
#  'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no'],
#  'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]}

# %% [markdown]
# * convert into Structured data using DataFrame:
#
# ---

# %%
x = pd.DataFrame(data)

# %%
x
# Out:
#   animal  age  visits priority
# 0    cat  2.5       1      yes
# 1    cat  3.0       3      yes
# 2  snake  0.5       2       no
# 3    dog  NaN       3      yes
# 4    dog  5.0       2       no
# 5    cat  2.0       3       no
# 6  snake  4.5       1       no
# 7    cat  NaN       1      yes
# 8    dog  7.0       2       no
# 9    dog  3.0       1       no

# %% [markdown]
# * Operations:
#
# ---

# %%
x['visits']>2
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: visits, dtype: bool

# %%
x[x['visits']>2]
# Out:
#   animal  age  visits priority
# 1    cat  3.0       3      yes
# 3    dog  NaN       3      yes
# 5    cat  2.0       3       no

# %%
x[x['animal'] == 'snake']
# Out:
#   animal  age  visits priority
# 2  snake  0.5       2       no
# 6  snake  4.5       1       no

# %% [markdown]
# * '&' operator:
#
# ---

# %%
x[ (x['animal'] == 'cat') & (x['visits'] <3) ]
# Out:
#   animal  age  visits priority
# 0    cat  2.5       1      yes
# 7    cat  NaN       1      yes

# %% [markdown]
# * ranging for column values:
#
# ---

# %%
x[x['visits'].between(1,5)]
# Out:
#   animal  age  visits priority
# 0    cat  2.5       1      yes
# 1    cat  3.0       3      yes
# 2  snake  0.5       2       no
# 3    dog  NaN       3      yes
# 4    dog  5.0       2       no
# 5    cat  2.0       3       no
# 6  snake  4.5       1       no
# 7    cat  NaN       1      yes
# 8    dog  7.0       2       no
# 9    dog  3.0       1       no

# %% [markdown]
# # Updating data (by calling corresponding rows and column):

# %%
x.loc[[8,1,2],'visits'] = 99

# %%
x
# Out:
#        animal  age  visits priority     8
# 0         cat  2.5       1      yes   NaN
# 1         cat  3.0      99      yes   NaN
# 2       snake  0.5      99       no   NaN
# 3         dog  NaN       3      yes   NaN
# 4         dog  5.0       2       no   NaN
# 5         cat  2.0       3       no   NaN
# 6       snake  4.5       6       no   NaN
# 7         cat  NaN       1      yes   NaN
# 8         dog  7.0      99       no   NaN
# 9         dog  3.0       1       no   NaN
# visits      6  6.0       6        6  99.0

# %%
df1 = pd.read_csv("/content/Admittance.csv")
df1
# Out:
#      Marks Admitted
# 0     1363       No
# 1     1792      Yes
# 2     1954      Yes
# 3     1653       No
# 4     1593       No
# ..     ...      ...
# 163   1722      Yes
# 164   1750      Yes
# 165   1555       No
# 166   1524       No
# 167   1461       No
#
# [168 rows x 2 columns]

# %% [markdown]
# # to Count the column values:

# %%
df1["Admitted"].value_counts()
# Out:
# Yes    94
# No     74
# Name: Admitted, dtype: int64

# %% [markdown]
# # replace / update data

# %% [markdown]
# * to Replace column values: using replace()
#
# ---

# %%
df1['Admitted'].replace('Yes',1)
# Out:
# 0      No
# 1       1
# 2       1
# 3      No
# 4      No
#        ..
# 163     1
# 164     1
# 165    No
# 166    No
# 167    No
# Name: Admitted, Length: 168, dtype: object

# %% [markdown]
# * to Replace column values: using map()

# %%
df1['Admitted'].map({'Yes':1,'No':0})
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 163    1
# 164    1
# 165    0
# 166    0
# 167    0
# Name: Admitted, Length: 168, dtype: int64

# %%
df3 = pd.DataFrame(data)

# %% [markdown]
# * to Replace null values: using replace()
#
# ---

# %%
df3['age'] = df3['age'].replace(np.nan,4)

# %%
df3
# Out:
#   animal  age  visits priority
# 0    cat  2.5       1      yes
# 1    cat  3.0       3      yes
# 2  snake  0.5       2       no
# 3    dog  4.0       3      yes
# 4    dog  5.0       2       no
# 5    cat  2.0       3       no
# 6  snake  4.5       1       no
# 7    cat  4.0       1      yes
# 8    dog  7.0       2       no
# 9    dog  3.0       1       no

# %%
df4 = pd.DataFrame(data)

# %% [markdown]
# # boolean outputs: isnull(), notnull(), isna()

# %%
df4.isnull()
# Out:
#    animal    age  visits  priority
# 0   False  False   False     False
# 1   False  False   False     False
# 2   False  False   False     False
# 3   False   True   False     False
# 4   False  False   False     False
# 5   False  False   False     False
# 6   False  False   False     False
# 7   False   True   False     False
# 8   False  False   False     False
# 9   False  False   False     False

# %%
df4.notnull()
# Out:
#    animal    age  visits  priority
# 0    True   True    True      True
# 1    True   True    True      True
# 2    True   True    True      True
# 3    True  False    True      True
# 4    True   True    True      True
# 5    True   True    True      True
# 6    True   True    True      True
# 7    True  False    True      True
# 8    True   True    True      True
# 9    True   True    True      True

# %%
df4.isna()
# Out:
#    animal    age  visits  priority
# 0   False  False   False     False
# 1   False  False   False     False
# 2   False  False   False     False
# 3   False   True   False     False
# 4   False  False   False     False
# 5   False  False   False     False
# 6   False  False   False     False
# 7   False   True   False     False
# 8   False  False   False     False
# 9   False  False   False     False

# %% [markdown]
# * to Replace null value: using fillna()
#
# ---

# %%
df4['age'].fillna(7,inplace=True)

# %%
df4
# Out:
#   animal  age  visits priority
# 0    cat  2.5       1      yes
# 1    cat  3.0       3      yes
# 2  snake  0.5       2       no
# 3    dog  7.0       3      yes
# 4    dog  5.0       2       no
# 5    cat  2.0       3       no
# 6  snake  4.5       1       no
# 7    cat  7.0       1      yes
# 8    dog  7.0       2       no
# 9    dog  3.0       1       no

# %% [markdown]
# # Adding new data

# %% [markdown]
# * to Add new row:
#
# ---

# %%
df4.loc[20] = ['rat',1,5,'yes']

# %%
df4
# Out:
#    animal  age  visits priority
# 0     cat  2.5       1      yes
# 1     cat  3.0       3      yes
# 2   snake  0.5       2       no
# 3     dog  7.0       3      yes
# 4     dog  5.0       2       no
# 5     cat  2.0       3       no
# 6   snake  4.5       1       no
# 7     cat  7.0       1      yes
# 8     dog  7.0       2       no
# 9     dog  3.0       1       no
# 20    rat  1.0       5      yes

# %%
df4.loc[20,'age'] = 2

# %%
df4
# Out:
#    animal  age  visits priority
# 0     cat  2.5       1      yes
# 1     cat  3.0       3      yes
# 2   snake  0.5       2       no
# 3     dog  7.0       3      yes
# 4     dog  5.0       2       no
# 5     cat  2.0       3       no
# 6   snake  4.5       1       no
# 7     cat  7.0       1      yes
# 8     dog  7.0       2       no
# 9     dog  3.0       1       no
# 20    rat  2.0       5      yes

# %%
l = [2,4,6,8,1,3,5,7,9,10,11]

# %% [markdown]
# * to Add new Column:
#
# ---

# %%
df4['population'] = l

# %%
df4
# Out:
#    animal  age  visits priority  population
# 0     cat  2.5       1      yes           2
# 1     cat  3.0       3      yes           4
# 2   snake  0.5       2       no           6
# 3     dog  7.0       3      yes           8
# 4     dog  5.0       2       no           1
# 5     cat  2.0       3       no           3
# 6   snake  4.5       1       no           5
# 7     cat  7.0       1      yes           7
# 8     dog  7.0       2       no           9
# 9     dog  3.0       1       no          10
# 20    rat  2.0       5      yes          11

# %% [markdown]
# * to update multiple column features of a row:
#
# ---

# %%
df4.loc[9,['animal','age','visits']] = ['tiger',6,5]
df4
# Out:
#    animal  age  visits priority  population
# 0     cat  2.5       1      yes           2
# 1     cat  3.0       3      yes           4
# 2   snake  0.5       2       no           6
# 3     dog  7.0       3      yes           8
# 4     dog  5.0       2       no           1
# 5     cat  2.0       3       no           3
# 6   snake  4.5       1       no           5
# 7     cat  7.0       1      yes           7
# 8     dog  7.0       2       no           9
# 9   tiger  6.0       5       no          10
# 20    rat  2.0       5      yes          11

# %%
df5 = pd.DataFrame(data)

# %% [markdown]
# # to Change the index designation:

# %%
df5 = pd.DataFrame(data, index = ['a','b','c','d','e','f','g','h','i','j'])

# %%
df5
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# * iloc: index based location (ie.using index number)
#
# ---

# %%
df5.iloc[4]
# Out:
# animal      dog
# age           5
# visits        2
# priority     no
# Name: e, dtype: object

# %%
df5.iloc[:4]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes

# %% [markdown]
# * loc : name based location (ie.using alphabets)
#
# ---

# %%
df5.loc['d']
# Out:
# animal      dog
# age         NaN
# visits        3
# priority    yes
# Name: d, dtype: object

# %% [markdown]
# # groupby()

# %% [markdown]
# * mean of age : using groupby()
#
# ---

# %%
df5.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.5
# dog      5.0
# snake    2.5
# Name: age, dtype: float64

# %% [markdown]
# * sum of age : using groupby()
#
# ---

# %%
df5.groupby('animal')['age'].sum()
# Out:
# animal
# cat       7.5
# dog      15.0
# snake     5.0
# Name: age, dtype: float64

# %% [markdown]
# * standard deviation of age : using groupby()
#
# ---

# %%
df5.groupby('animal')['age'].std()
# Out:
# animal
# cat      0.500000
# dog      2.000000
# snake    2.828427
# Name: age, dtype: float64

# %% [markdown]
# # sorting

# %% [markdown]
# * sorting rows based on column values:
#
# ---

# %%
df5.sort_values(['visits'],ascending=[True])
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# j    dog  3.0       1       no
# c  snake  0.5       2       no
# e    dog  5.0       2       no
# i    dog  7.0       2       no
# b    cat  3.0       3      yes
# d    dog  NaN       3      yes
# f    cat  2.0       3       no

# %% [markdown]
# * sorting rows based on multiple column values:
#
# ---

# %%
df5.sort_values(['visits','age'],ascending=[True, False])
# Out:
#   animal  age  visits priority
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# a    cat  2.5       1      yes
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# c  snake  0.5       2       no
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# d    dog  NaN       3      yes

# %%
df5.sort_values(['animal','visits','age'],ascending=[True,True,False])
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# h    cat  NaN       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# d    dog  NaN       3      yes
# g  snake  4.5       1       no
# c  snake  0.5       2       no
